# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newsapi import NewsApiClient
import requests

analyzer = SentimentIntensityAnalyzer()


# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ngond\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
# YOUR CODE HERE!
load_dotenv()
apikey = os.getenv("newsapi")

# %%
bitcoin_url='https://newsapi.org/v2/everything?q=bitcoin&apiKey='+apikey
ethereum_url='https://newsapi.org/v2/everything?q=ethereum&apiKey='+apikey

# %%
# btc_reponse_data=requests.get(bitcoin_url).json()
# eth_reponse_data=requests.get(ethereum_url).json()

# %%
def get_articles_df(json_obj):
    
    sentiments = []

    for article in json_obj["articles"]:
        try:
            text = article["content"]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            
            sentiments.append({
                "text": text,
                "date": date,
                "compound": compound,
                "positive": pos,
                "negative": neg,
                "neutral": neu
                
            })
            
        except AttributeError:
            pass

    df = pd.DataFrame(sentiments)

    cols = [ "text", "compound", "positive", "negative", "neutral"]
    df = df[cols]

    return df

# %%
# # Create a newsapi client
# # YOUR CODE HERE!
# newsapi = NewsApiClient(api_key=apikey)
newsapi = NewsApiClient(api_key=apikey)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_reponse_data = newsapi.get_everything(q='bitcoin',language='en')
get_articles_df(btc_reponse_data)['text']
# Out:
# 0     A similar hoax earlier this year tied Walmart ...
# 1     Theres a big new presence slurping up power fr...
# 2     For all the talk of democratizing finance, the...
# 3     In keeping with a previous announcement, AMC t...
# 4     Representation of cryptocurrency Bitcoin is pl...
# 5     A representation of the virtual cryptocurrency...
# 6     A representation of the virtual cryptocurrency...
# 7     Posted \r\nBitcoin climbed to a record high on...
# 8     A representation of the virtual cryptocurrency...
# 9     By Reuters Staff\r\nSINGAPORE (Reuters) - Bitc...
# 10    STR/NurPhoto via Getty Images\r\nThe first-eve...
# 11    Bitcoin artwork displayed at the Bitcoin 2021 ...
# 12    * Cryotocurrency gets boost from ETF bitcoin f...
# 13    Ether.\r\nNurPhoto\r\n<ul><li>The approval of ...
# 14    Bitcoin seen on display.\r\nRafael Henrique/SO...
# 15    Bitcoin was trading over 7% higher on Monday m...
# 16    Australian Baseball League club Perth Heat wil...
# 17    A passenger (R) talks to an airline employee o...
# 18    * Bitcoin breaks past $68,000; Ether nears $5k...
# 19    Representations of the virtual currency Bitcoi...
# Name: text, dtype: object

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_reponse_data = newsapi.get_everything(q='ethereum',language='en')
get_articles_df(eth_reponse_data)['text']
# Out:
# 0     In keeping with a previous announcement, AMC t...
# 1     Ethereum and bitcoin are the two biggest crypt...
# 2     Elon Musk\r\npicture alliance / Getty Images\r...
# 3     Cryptocurrency and business continuity line im...
# 4     Apple CEO Tim Cook said he owns cryptocurrency...
# 5     With crypto rewards cards, a small percentage ...
# 6     Bitcoin and Ethereum.\r\nNurPhoto / Getty Imag...
# 7     Representations of cryptocurrencies Bitcoin, E...
# 8     Grill burger chain Burger King announced a par...
# 9     Rahul Rai, co-head of Market Neutral at BlockT...
# 10    Hours ago, a website appeared online with the ...
# 11    Ether, the second-largest cryptocurrency, soar...
# 12    The worlds second most valuable cryptocurrency...
# 13    NEW YORK, Nov 8 (Reuters) - Inflows into bitco...
# 14    An American Airlines Airbus A321-200 plane tak...
# 15    The process started Thursday at 6:13 p.m. New ...
# 16    The digital currency space is contracting afte...
# 17    Now available as an NFT.\r\nLionsgate/Miramax\...
# 18    A representation of the virtual cryptocurrency...
# 19    By Reuters Staff\r\nFILE PHOTO: A representati...
# Name: text, dtype: object

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!

btc_sent_score_df= get_articles_df(btc_reponse_data)

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
eth_sent_score_df = get_articles_df(eth_reponse_data)

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_sent_score_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.166550   0.045700   0.005300   0.949000
# std     0.288800   0.067315   0.016633   0.065559
# min    -0.273200   0.000000   0.000000   0.801000
# 25%     0.000000   0.000000   0.000000   0.896500
# 50%     0.000000   0.000000   0.000000   1.000000
# 75%     0.463275   0.103500   0.000000   1.000000
# max     0.755800   0.199000   0.063000   1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_sent_score_df.describe()
# Out:
#         compound   positive  negative    neutral
# count  20.000000  20.000000      20.0  20.000000
# mean    0.305170   0.069100       0.0   0.930900
# std     0.304142   0.074103       0.0   0.074103
# min     0.000000   0.000000       0.0   0.779000
# 25%     0.000000   0.000000       0.0   0.896000
# 50%     0.381550   0.074000       0.0   0.926000
# 75%     0.530600   0.104000       0.0   1.000000
# max     0.822500   0.221000       0.0   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: *bitcoin has the highest mean positive score*
#
# Q: Which coin had the highest compound score?
#
# A: *Ethereum has the hightest compound score*
#
# Q. Which coin had the highest positive score?
#
# A: *ethereum has the highest positive score*

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# Code to download corpora
import nltk
nltk.download('stopwords')
nltk.download('reuters')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ngond\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\ngond\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ngond\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

vectorizer=CountVectorizer(stop_words='english')

def get_text_from_df (dataFrame_obj):
    
    text = [word.lower() for word in dataFrame_obj.text.to_list()]
    text = ('').join(text)
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    text=regex.sub('',text)

    return text

def process_text(text):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

#[get_text_from_df(btc_sent_score_df)]
def get_word_count(text):
    X= vectorizer.fit_transform([text] )
    # Retrieve unique words list
    words = vectorizer.get_feature_names()



    words_df = pd.DataFrame(
        list(zip(words, np.ravel(X.sum(axis=0)))), columns=["Word", "Word_Count"]
    )
    print(words_df.sort_values('Word_Count',ascending=False).head(10))

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()


# Create a list of stopwords
# YOUR CODE HERE!
sw=list((set(stopwords.words('english'))))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!
btc_text = get_text_from_df(btc_sent_score_df)
eth_text = get_text_from_df(eth_sent_score_df)

#Find irrelevant top words
get_word_count(btc_text)
get_word_count(eth_text)

#add reuters to the list of stopwords
sw= list(set(sw).union({'seen'}))
# Out:
#                Word  Word_Count
# 26          bitcoin          22
# 207         reuters           7
# 232           taken           6
# 124    illustration           6
# 166             new           5
# 71   cryptocurrency           5
# 184         picture           5
# 202          record           4
# 216            seen           4
# 169             oct           4
#                  Word  Word_Count
# 97           ethereum           9
# 82     cryptocurrency           7
# 29            bitcoin           7
# 287              york           4
# 151            market           4
# 80   cryptocurrencies           4
# 91            digital           3
# 96              ether           3
# 115             getty           3
# 124      illustration           3
# C:\Users\ngond\anaconda3_1\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\ngond\anaconda3_1\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    result = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    result = [word.lower() for word in result]
    
    # Remove the stop words
    sw= list((set(stopwords.words('english')).union({'reuters'})))

    tokens = [word.lower() for word in result if word.lower() not in sw]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
btc_sent_score_df['tokens'] = btc_sent_score_df.apply(lambda row : tokenizer(row['text']),axis=1)

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_sent_score_df['tokens']= eth_sent_score_df.apply(lambda row : tokenizer(row['text']),axis=1)

# %%
btc_sent_score_df
# Out:
#                                                  text  compound  positive  \
# 0   A similar hoax earlier this year tied Walmart ...   -0.2732     0.000
# 1   Theres a big new presence slurping up power fr...    0.3612     0.096
# 2   For all the talk of democratizing finance, the...    0.0000     0.000
# 3   In keeping with a previous announcement, AMC t...    0.5719     0.153
# 4   Representation of cryptocurrency Bitcoin is pl...    0.0000     0.000
# 5   A representation of the virtual cryptocurrency...    0.0000     0.000
# 6   A representation of the virtual cryptocurrency...    0.0000     0.000
# 7   Posted \r\nBitcoin climbed to a record high on...    0.4588     0.103
# 8   A representation of the virtual cryptocurrency...    0.0000     0.000
# 9   By Reuters Staff\r\nSINGAPORE (Reuters) - Bitc...    0.0000     0.000
# 10  STR/NurPhoto via Getty Images\r\nThe first-eve...    0.0000     0.000
# 11  Bitcoin artwork displayed at the Bitcoin 2021 ...    0.5719     0.148
# 12  * Cryotocurrency gets boost from ETF bitcoin f...    0.7558     0.199
# 13  Ether.\r\nNurPhoto\r\n<ul><li>The approval of ...    0.4767     0.110
# 14  Bitcoin seen on display.\r\nRafael Henrique/SO...    0.5106     0.105
# 15  Bitcoin was trading over 7% higher on Monday m...    0.0000     0.000
# 16  Australian Baseball League club Perth Heat wil...   -0.1027     0.000
# 17  A passenger (R) talks to an airline employee o...    0.0000     0.000
# 18  * Bitcoin breaks past $68,000; Ether nears $5k...    0.0000     0.000
# 19  Representations of the virtual currency Bitcoi...    0.0000     0.000
#
#     negative  neutral                                             tokens
# 0      0.063    0.937  [similar, hoax, earlier, year, tied, walmart, ...
# 1      0.000    0.904  [theres, big, new, presence, slurping, power, ...
# 2      0.000    1.000  [talk, democratizing, finance, vast, majority,...
# 3      0.000    0.847  [keeping, previous, announcement, amc, theater...
# 4      0.000    1.000  [representation, cryptocurrency, bitcoin, plac...
# 5      0.000    1.000  [representation, virtual, cryptocurrency, bitc...
# 6      0.000    1.000  [representation, virtual, cryptocurrency, bitc...
# 7      0.000    0.897  [posted, bitcoin, climbed, record, high, wedne...
# 8      0.000    1.000  [representation, virtual, cryptocurrency, bitc...
# 9      0.000    1.000  [staffsingapore, bitcoin, hit, sixmonth, high,...
# 10     0.000    1.000  [strnurphoto, via, getty, imagesthe, firstever...
# 11     0.000    0.852  [bitcoin, artwork, displayed, bitcoin, convent...
# 12     0.000    0.801  [cryotocurrency, get, boost, etf, bitcoin, fut...
# 13     0.000    0.890  [ethernurphotoullithe, approval, bitcoin, futu...
# 14     0.000    0.895  [bitcoin, seen, displayrafael, henriquesopa, i...
# 15     0.000    1.000  [bitcoin, wa, trading, higher, monday, morning...
# 16     0.043    0.957  [australian, baseball, league, club, perth, he...
# 17     0.000    1.000  [passenger, r, talk, airline, employee, mexica...
# 18     0.000    1.000  [bitcoin, break, past, ether, nears, k, pull, ...
# 19     0.000    1.000  [representations, virtual, currency, bitcoin, ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!


def generate_ngrams(DF) :
    processed =process_text(('').join([word.lower() for word in DF.text.to_list()]))
    bigram_counts = Counter(ngrams(processed, n=2))
    #print(sorted([(k,v) for k,v in enumerate(bigram_counts) if k >2]))
    print(dict(bigram_counts.most_common(20)))

def bigram_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    processed = process_text(big_string)
    bigrams = ngrams(processed, n=2)
    top_10 = dict(Counter(bigrams).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['bigram', 'count'])

generate_ngrams(btc_sent_score_df)
# Out:
# {('reuters', 'bitcoin'): 6, ('illustration', 'taken'): 5, ('cryptocurrency', 'bitcoin'): 4, ('oct', 'reuters'): 4, ('picture', 'illustration'): 4, ('representation', 'virtual'): 3, ('virtual', 'cryptocurrency'): 3, ('bitcoin', 'seen'): 3, ('seen', 'picture'): 3, ('taken', 'october'): 3, ('october', 'reutersedgar'): 3, ('wa', 'trading'): 3, ('kong', 'oct'): 2, ('bitcoin', 'fell'): 2, ('charsa', 'representation'): 2, ('bitcoin', 'futuresbased'): 2, ('exchangetraded', 'fund'): 2, ('bitcoin', 'hit'): 2, ('hit', 'sixmonth'): 2, ('sixmonth', 'high'): 2}

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
generate_ngrams(eth_sent_score_df)
# Out:
# {('illustration', 'taken'): 3, ('taken', 'june'): 3, ('new', 'york'): 2, ('york', 'time'): 2, ('bitcoin', 'ethereum'): 2, ('ethereum', 'dogecoin'): 2, ('york', 'nov'): 2, ('los', 'angeles'): 2, ('representation', 'virtual'): 2, ('virtual', 'cryptocurrency'): 2, ('cryptocurrency', 'ethereum'): 2, ('ethereum', 'seen'): 2, ('seen', 'among'): 2, ('among', 'representation'): 2, ('representation', 'cryptocurrencies'): 2, ('cryptocurrencies', 'picture'): 2, ('picture', 'illustration'): 2, ('keeping', 'previous'): 1, ('previous', 'announcement'): 1, ('announcement', 'amc'): 1}

# %%
tokenizer(btc_text)
# Out:
# ['similar',
#  'hoax',
#  'earlier',
#  'year',
#  'tied',
#  'walmart',
#  'litecoinif',
#  'buy',
#  'something',
#  'verge',
#  'link',
#  'vox',
#  'medium',
#  'may',
#  'earn',
#  'commission',
#  'see',
#  'ethic',
#  'statementphoto',
#  'illustration',
#  'thiago',
#  'prudencios',
#  'charstheres',
#  'big',
#  'new',
#  'presence',
#  'slurping',
#  'power',
#  'u',
#  'grid',
#  'growing',
#  'bitcoin',
#  'miner',
#  'new',
#  'research',
#  'show',
#  'u',
#  'ha',
#  'overtaken',
#  'china',
#  'top',
#  'global',
#  'destination',
#  'bitcoin',
#  'mining',
#  'charsfor',
#  'talk',
#  'democratizing',
#  'finance',
#  'vast',
#  'majority',
#  'bitcoin',
#  'continues',
#  'owned',
#  'relative',
#  'handful',
#  'investorsas',
#  'flagged',
#  'bloomberg',
#  'newly',
#  'released',
#  'data',
#  'national',
#  'bureau',
#  'charsin',
#  'keeping',
#  'previous',
#  'announcement',
#  'amc',
#  'theater',
#  'accept',
#  'cryptocurrencies',
#  'payment',
#  'online',
#  'purchasesbitcoin',
#  'ethereum',
#  'bitcoin',
#  'cash',
#  'litecoin',
#  'acceptedpreviously',
#  'compa',
#  'charsrepresentation',
#  'cryptocurrency',
#  'bitcoin',
#  'placed',
#  'pc',
#  'motherboard',
#  'illustration',
#  'taken',
#  'june',
#  'reutersdado',
#  'ruvicillustrationhong',
#  'kong',
#  'oct',
#  'bitcoin',
#  'fell',
#  'slightly',
#  'charsa',
#  'representation',
#  'virtual',
#  'cryptocurrency',
#  'bitcoin',
#  'seen',
#  'picture',
#  'illustration',
#  'taken',
#  'october',
#  'reutersedgar',
#  'sulondon',
#  'oct',
#  'bitcoin',
#  'cusp',
#  'alltime',
#  'hi',
#  'charsa',
#  'representation',
#  'virtual',
#  'cryptocurrency',
#  'bitcoin',
#  'seen',
#  'picture',
#  'illustration',
#  'taken',
#  'october',
#  'reutersedgar',
#  'suhong',
#  'kong',
#  'oct',
#  'bitcoin',
#  'hovered',
#  'record',
#  'level',
#  'charsposted',
#  'bitcoin',
#  'climbed',
#  'record',
#  'high',
#  'wednesday',
#  'amid',
#  'new',
#  'interest',
#  'first',
#  'u',
#  'bitcoin',
#  'futuresbased',
#  'exchangetraded',
#  'fund',
#  'come',
#  'market',
#  'conway',
#  'g',
#  'gittens',
#  'ha',
#  'morea',
#  'representation',
#  'virtual',
#  'cryptocurrency',
#  'bitcoin',
#  'seen',
#  'picture',
#  'illustration',
#  'taken',
#  'october',
#  'reutersedgar',
#  'susingapore',
#  'oct',
#  'bitcoin',
#  'hit',
#  'sixmonth',
#  'high',
#  'wa',
#  'charsby',
#  'staffsingapore',
#  'bitcoin',
#  'hit',
#  'sixmonth',
#  'high',
#  'wa',
#  'within',
#  'striking',
#  'distance',
#  'record',
#  'tuesday',
#  'trader',
#  'bet',
#  'anticipated',
#  'listing',
#  'futuresbased',
#  'u',
#  'exchange',
#  'tra',
#  'charsstrnurphoto',
#  'via',
#  'getty',
#  'imagesthe',
#  'firstever',
#  'bitcoinlinked',
#  'exchangetraded',
#  'fund',
#  'begin',
#  'trading',
#  'tuesday',
#  'provider',
#  'proshares',
#  'said',
#  'statement',
#  'launch',
#  'mark',
#  'another',
#  'milestone',
#  'charsbitcoin',
#  'artwork',
#  'displayed',
#  'bitcoin',
#  'conventionmarco',
#  'bellogetty',
#  'imagesthe',
#  'security',
#  'exchange',
#  'commission',
#  'make',
#  'decision',
#  'alternative',
#  'asset',
#  'management',
#  'firm',
#  'valkyrie',
#  'pr',
#  'char',
#  'cryotocurrency',
#  'get',
#  'boost',
#  'etf',
#  'bitcoin',
#  'future',
#  'launch',
#  'etf',
#  'bitcoins',
#  'may',
#  'higher',
#  'cost',
#  'v',
#  'buying',
#  'actual',
#  'cryptos',
#  'benefit',
#  'owning',
#  'etf',
#  'lauded',
#  'many',
#  'despite',
#  'risk',
#  'tuesd',
#  'charsethernurphotoullithe',
#  'approval',
#  'bitcoin',
#  'futuresbased',
#  'etf',
#  'mean',
#  'similar',
#  'offering',
#  'ether',
#  'imminentlilibloomberg',
#  'analyst',
#  'believe',
#  'first',
#  'ether',
#  'futuresbased',
#  'etf',
#  'could',
#  'launch',
#  'charsbitcoin',
#  'seen',
#  'displayrafael',
#  'henriquesopa',
#  'imageslightrocket',
#  'via',
#  'getty',
#  'imagesbitcoin',
#  'extending',
#  'recent',
#  'ascent',
#  'test',
#  'new',
#  'price',
#  'record',
#  'crypto',
#  'hodlers',
#  'cheer',
#  'future',
#  'exchangetrad',
#  'charsbitcoin',
#  'wa',
#  'trading',
#  'higher',
#  'monday',
#  'morning',
#  'priced',
#  'around',
#  'per',
#  'coinether',
#  'wa',
#  'trading',
#  'higher',
#  'priced',
#  'dogecoin',
#  'meanwhile',
#  'wa',
#  'trading',
#  'little',
#  'charsaustralian',
#  'baseball',
#  'league',
#  'club',
#  'perth',
#  'heat',
#  'pay',
#  'player',
#  'bitcoin',
#  'partnering',
#  'cryptocurrency',
#  'payment',
#  'company',
#  'deal',
#  'claim',
#  'world',
#  'first',
#  'professional',
#  'sporthea',
#  'charsa',
#  'passenger',
#  'r',
#  'talk',
#  'airline',
#  'employee',
#  'mexican',
#  'lowcost',
#  'air',
#  'carrier',
#  'volaris',
#  'benito',
#  'juarez',
#  'international',
#  'airport',
#  'mexico',
#  'city',
#  'mexico',
#  'january',
#  'picture',
#  'taken',
#  'january',
#  'char',
#  'bitcoin',
#  'break',
#  'past',
#  'ether',
#  'nears',
#  'k',
#  'pull',
#  'back',
#  'later',
#  'coingecko',
#  'put',
#  'crypto',
#  'market',
#  'cap',
#  'trillion',
#  'flow',
#  'surge',
#  'momentum',
#  'run',
#  'hot',
#  'add',
#  'new',
#  'comment',
#  'update',
#  'pric',
#  'charsrepresentations',
#  'virtual',
#  'currency',
#  'bitcoin',
#  'stand',
#  'motherboard',
#  'picture',
#  'illustration',
#  'taken',
#  'may',
#  'reutersdado',
#  'ruvicfile',
#  'photolondon',
#  'nov',
#  'bitcoin',
#  'fell',
#  'char']

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!

import itertools


token_count(list(itertools.chain(*btc_sent_score_df.tokens)),10)
# Out:
# [('bitcoin', 25),
#  ('char', 19),
#  ('illustration', 6),
#  ('taken', 6),
#  ('new', 5),
#  ('cryptocurrency', 5),
#  ('picture', 5),
#  ('wa', 5),
#  ('us', 4),
#  ('representation', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
token_count(list(itertools.chain(*eth_sent_score_df.tokens)),10)
# Out:
# [('char', 20),
#  ('ethereum', 10),
#  ('bitcoin', 8),
#  ('cryptocurrency', 8),
#  ('cryptocurrencies', 4),
#  ('york', 4),
#  ('market', 4),
#  ('ether', 4),
#  ('representation', 4),
#  ('getty', 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
# def get_wordcloud(df):
#     big_string = ' '.join(list(itertools.chain(*df.tokens)))
#     input_text = process_text(big_string)
#     wc = WordCloud().generate(big_string)
#    # print(big_string)
#     plt.imshow(wc)
# get_wordcloud(btc_sent_score_df)

input_text =process_text((' ').join(list(itertools.chain(*btc_sent_score_df.tokens))))
input_text =(' ').join(input_text)
wc = WordCloud().generate(input_text)
plt.imshow(wc)
plt.show()
wc.to_file('btc.png')

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---
