# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
import csv
# %ls *
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 8A1A-7026
#
#  Directory of C:\Users\ngond\python-homework\PyRamen
#
# 08/27/2021  09:30 PM    <DIR>          .
# 08/27/2021  09:30 PM    <DIR>          ..
# 08/27/2021  04:43 PM                 0 .gitkeep
# 08/27/2021  07:17 PM    <DIR>          .ipynb_checkpoints
# 08/27/2021  09:30 PM        49,410,244 main.ipynb
# 08/27/2021  07:14 PM    <DIR>          Resources
#                2 File(s)     49,410,244 bytes
#                4 Dir(s)  1,787,995,463,680 bytes free

# %%
menuCSVPath=Path.cwd()/'Resources'/'menu_data.csv'
salesCSVPath=Path.cwd()/'Resources'/'sales_data.csv'
txtfilePath=Path.cwd()/'report.txt'

# %%
menu_df=pd.read_csv(menuCSVPath)
sales_df=pd.read_csv(salesCSVPath)
menu=[]
sales=[]

# %%
with open(menuCSVPath,'r') as csvfile:
    
    csvreader=csv.reader(csvfile,delimiter=',')
    
    next(csvreader)
    
    for row in csvreader:
        item=row[0]
        category=row[1]
        description=row[2]
        price=float(row[3])
        cost=int(row[4])
        menu.append([item,category,description,price,cost])

# %%
with open(salesCSVPath,'r') as csvfile:
    
    csvreader=csv.reader(csvfile,delimiter=',')
    
    next(csvreader)
    
    for row in csvreader:
        Line_Item_ID=int(row[0])
        Date=row[1]
        Credit_Card_Number=int(row[2])
        Quantity=int(row[3])
        Menu_item=row[4]
        sales.append([Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_item])

# %%
#Initialize an empty report dictionary to hold the future aggregated per-product results.
report={}
record_count=0

#loop through sales list and populate report dictionary with initial values
for sale in sales:
    
    #for each row of sales set data to their own variables:
    quantity=sale[3]
    menu_item=sale[4]
    
    #check if initial key value pairs exists, otherwise populate dictionary with new data
    if menu_item not in report.keys():
        report[menu_item]={
            "01-count": 0,
            "02-revenue": 0,
            "03-cogs": 0,
            "04-profit": 0
            }
 
    
    #create nested loop by looping through every record in menu
    #create new variable and set it to each menu data
    
    for items in menu:
        
        item=items[0]
        price=items[3]
        cost=items[4]
        
        #calculate profit
        profit=price-cost
        
        #if menu item is equal to the item in sales list
        #calcule cumulative sums for report metrics
        if menu_item ==item:
            report[menu_item]["01-count"] += quantity
            report[menu_item]["02-revenue"] += price * quantity
            report[menu_item]["03-cogs"] += cost * quantity
            report[menu_item]["04-profit"] += profit * quantity
        #or else print that the items are not matching
        else:
            print(f'{menu_item} does not equal {item}! NO MATCH!".')

# %%
with open(txtfilePath, "w") as txt_file:
    for key, value in report.items():

        line = f"{key} {value}\n"
        txt_file.write(line)

# %%
df=sales_df.merge(menu_df,left_on='Menu_Item',right_on='item')
df['profit']=df['price']-df['cost']
df['revenue']=df['price']*df['Quantity']
df['cogs']=df['cost']*df['Quantity']
df.groupby(by='item').sum()
# Out:
#                                                 Line_Item_ID  \
# item
# burnt garlic tonkotsu ramen                      252065727.0
# miso crab ramen                                  245834699.0
# nagomi shoyu                                     248863214.0
# shio ramen                                       251597212.0
# soft-shell miso crab ramen                       250939165.0
# spicy miso ramen                                 248767867.0
# tonkotsu ramen                                   249868856.0
# tori paitan ramen                                252738187.0
# truffle butter ramen                             249741157.0
# vegetarian curry + king trumpet mushroom ramen   245741009.0
# vegetarian spicy miso                            251063657.0
#
#                                                 Credit_Card_Number  Quantity  \
# item
# burnt garlic tonkotsu ramen                           3.376617e+19    9070.0
# miso crab ramen                                       3.256509e+19    8890.0
# nagomi shoyu                                          3.280075e+19    9132.0
# shio ramen                                            3.324208e+19    9180.0
# soft-shell miso crab ramen                            3.331446e+19    9130.0
# spicy miso ramen                                      3.498825e+19    9238.0
# tonkotsu ramen                                        3.393332e+19    9288.0
# tori paitan ramen                                     3.374608e+19    9156.0
# truffle butter ramen                                  3.407522e+19    8982.0
# vegetarian curry + king trumpet mushroom ramen        3.293250e+19    8824.0
# vegetarian spicy miso                                 3.436609e+19    9216.0
#
#                                                   price     cost   profit  \
# item
# burnt garlic tonkotsu ramen                     94780.0  40620.0  54160.0
# miso crab ramen                                 78648.0  39324.0  39324.0
# nagomi shoyu                                    73260.0  33300.0  39960.0
# shio ramen                                      74184.0  33720.0  40464.0
# soft-shell miso crab ramen                      94388.0  47194.0  47194.0
# spicy miso ramen                                81624.0  34010.0  47614.0
# tonkotsu ramen                                  88400.0  40800.0  47600.0
# tori paitan ramen                               88634.0  40908.0  47726.0
# truffle butter ramen                            94164.0  47082.0  47082.0
# vegetarian curry + king trumpet mushroom ramen  86918.0  46802.0  40116.0
# vegetarian spicy miso                           81864.0  34110.0  47754.0
#
#                                                  revenue     cogs
# item
# burnt garlic tonkotsu ramen                     126980.0  54420.0
# miso crab ramen                                 106680.0  53340.0
# nagomi shoyu                                    100452.0  45660.0
# shio ramen                                      100980.0  45900.0
# soft-shell miso crab ramen                      127820.0  63910.0
# spicy miso ramen                                110856.0  46190.0
# tonkotsu ramen                                  120744.0  55728.0
# tori paitan ramen                               119028.0  54936.0
# truffle butter ramen                            125748.0  62874.0
# vegetarian curry + king trumpet mushroom ramen  114712.0  61768.0
# vegetarian spicy miso                           110592.0  46080.0
